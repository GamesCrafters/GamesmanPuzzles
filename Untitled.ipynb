# %%
from puzzlesolver.puzzles.graphpuzzle import GraphPuzzle as gp
import matplotlib as plt
import networkx as nx

# %%
p1 = gp(1)
p2 = gp(2)
p1.setMove(p2)
p3 = gp(3)
p3.setMove(p1)
p3.setMove(p1, movetype='bi')
nx.draw_networkx(p1.graph)

# %%
p3.graph
